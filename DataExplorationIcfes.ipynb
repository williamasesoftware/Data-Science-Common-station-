# %% [markdown]
# # Data Exploration

# %% [markdown]
# Hey! During this first step, please, take a look at the data set and just explore it, find the types of each column and try to find interesting things. Don't worry about data cleaning. Just exploration for now.
# You can answer the following questions:
# - How many columns there are
# - The type of each column
# - The different values that a column can take
# - Which do you think are the most important columns? If we are looking at the overall score.
#
# Go wild! (Remember, so far, only exploration).

# %%
# Packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/wdmoreno/Downloads/Saber_11__2019-2.csv')
df.head()
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\536344218.py:1: DtypeWarning: Columns (76,78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/wdmoreno/Downloads/Saber_11__2019-2.csv')
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
# 2                 TI          COLOMBIA           M  06/02/2001 12:00:00 AM
# 3                 TI          COLOMBIA           M  04/26/2002 12:00:00 AM
# 4                 TI          COLOMBIA           M  02/05/2002 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
# ...

# %%
num_columns = len(df.columns)
print(f"The dataframe has {num_columns} columns.")
# Out:
# The dataframe has 82 columns.

# %%
column_types = df.dtypes
print("Column types:")
print(column_types)
# Out:
# Column types:
# ESTU_TIPODOCUMENTO           object
# ESTU_NACIONALIDAD            object
# ESTU_GENERO                  object
# ESTU_FECHANACIMIENTO         object
# PERIODO                       int64
#                              ...
# ESTU_INSE_INDIVIDUAL         object
# ESTU_NSE_INDIVIDUAL          object
# ESTU_NSE_ESTABLECIMIENTO    float64
# ESTU_ESTADOINVESTIGACION     object
# ESTU_GENERACION-E            object
# Length: 82, dtype: object

# %%
column_name="ESTU_NACIONALIDAD"
unique_values = df[column_name].unique()
print(f"The {column_name} column has {len(unique_values)} unique values:")
print(unique_values)
# Out:
# The ESTU_NACIONALIDAD column has 33 unique values:
# ['COLOMBIA' 'VENEZUELA' 'ESPAÑA' 'ECUADOR' 'CROACIA' 'PERÚ' 'ITALIA'
#  'ESTADOS UNIDOS' 'FRANCIA' 'EL SALVADOR' 'COSTA RICA' 'ARGENTINA'
#  'ALBANIA' 'TAIWAN' 'CUBA' 'CHILE' 'MÉXICO' 'ALEMANIA' 'ARUBA' 'BRASIL'
#  'REINO UNIDO' 'DINAMARCA' 'PAÍSES BAJOS - HOLANDA' 'COMORAS'
#  'REPÚBLICA DOMINICANA' 'BOLIVIA' 'CHINA' 'BÉLGICA' 'PANAMÁ' 'AFGANISTÁN'
#  'COREA DEL NORTE' 'CURAZAO' 'VANUATU']

# %%
corr=df.corr ()
# plot the heatmap
sns.heatmap(corr, 
        xticklabels=corr.columns,
        yticklabels=corr.columns,cmap="Blues")
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2659383237.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr ()
# <AxesSubplot: >

# %%
df.shape
print("Numbers of rows: ", df.shape[0])
print("Numbers of columns: ", df.shape[1])
# Out:
# Numbers of rows:  546212
# Numbers of columns:  82

# %%
df.describe()
# Out:
#         PERIODO  COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  \
# count  546212.0      546212.000000                   5.462120e+05
# mean    20194.0      197397.840712                   2.038424e+11
# std         0.0      229636.502160                   9.221826e+10
# min     20194.0          75.000000                   1.050010e+11
# 25%     20194.0       45732.000000                   1.170500e+11
# 50%     20194.0      113076.000000                   1.732085e+11
# 75%     20194.0      194779.000000                   3.050010e+11
# max     20194.0      728303.000000                   8.548740e+11
#
#        COLE_COD_DANE_SEDE  COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# count        5.462120e+05             546212.000000             546212.000000
# mean         2.044208e+11              32755.704584                 32.516563
# std          9.302404e+10              26364.009436                 26.340054
# ...

# %%
df.value_counts("ESTU_GENERO")
# Out:
# ESTU_GENERO
# F    295994
# M    250097
# -       121
# dtype: int64

# %%
df["FAMI_ESTRATOVIVIENDA"].value_counts()
# Out:
# Estrato 2      188314
# Estrato 1      159977
# Estrato 3      108692
# -               34481
# Estrato 4       25810
# Sin Estrato     17177
# Estrato 5        8024
# Estrato 6        3711
# Name: FAMI_ESTRATOVIVIENDA, dtype: int64

# %%
df["FAMI_EDUCACIONPADRE"].value_counts()
# Out:
# Secundaria (Bachillerato) completa      117488
# Primaria incompleta                     101387
# Secundaria (Bachillerato) incompleta     71295
# Primaria completa                        54141
# Educación profesional completa           46404
# Técnica o tecnológica completa           35367
# No sabe                                  32104
# -                                        22235
# Ninguno                                  20106
# Técnica o tecnológica incompleta         10957
# Educación profesional incompleta         10150
# Postgrado                                 9437
# No Aplica                                 6849
# Name: FAMI_EDUCACIONPADRE, dtype: int64

# %%
df["FAMI_ESTRATOVIVIENDA"].value_counts()
df.groupby(['FAMI_ESTRATOVIVIENDA']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (10,10)
sns.boxplot( x = 'FAMI_ESTRATOVIVIENDA',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3862285811.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_ESTRATOVIVIENDA']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='FAMI_ESTRATOVIVIENDA', ylabel='PUNT_GLOBAL'>

# %%
df["ESTU_GENERO"].value_counts()
df.groupby(['ESTU_GENERO']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (10,10)
sns.boxplot( x = 'ESTU_GENERO',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\818918807.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_GENERO']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='ESTU_GENERO', ylabel='PUNT_GLOBAL'>

# %%
df.groupby(['FAMI_EDUCACIONPADRE']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\17816652.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_EDUCACIONPADRE']).mean()["PUNT_GLOBAL"]
# FAMI_EDUCACIONPADRE
# -                                       221.901102
# Educación profesional completa          277.452569
# Educación profesional incompleta        274.755271
# Ninguno                                 211.367751
# No Aplica                               253.514674
# No sabe                                 251.556909
# Postgrado                               311.812652
# Primaria completa                       235.541198
# Primaria incompleta                     230.493979
# Secundaria (Bachillerato) completa      249.891734
# Secundaria (Bachillerato) incompleta    241.569998
# ...

# %%
df.groupby(['FAMI_EDUCACIONMADRE']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3797868041.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_EDUCACIONMADRE']).mean()["PUNT_GLOBAL"]
# FAMI_EDUCACIONMADRE
# -                                       217.846939
# Educación profesional completa          277.332342
# Educación profesional incompleta        273.746851
# Ninguno                                 207.913572
# No Aplica                               226.886216
# No sabe                                 249.188356
# Postgrado                               307.674503
# Primaria completa                       231.742520
# Primaria incompleta                     225.832380
# Secundaria (Bachillerato) completa      248.013325
# Secundaria (Bachillerato) incompleta    238.519456
# ...

# %%
df.groupby(['FAMI_TRABAJOLABORPADRE']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2165112887.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_TRABAJOLABORPADRE']).mean()["PUNT_GLOBAL"]
# FAMI_TRABAJOLABORPADRE
# -                                                                                                       244.584193
# Es agricultor, pesquero o jornalero                                                                     228.955530
# Es dueño de un negocio grande, tiene un cargo de nivel directivo o gerencial                            262.473924
# Es dueño de un negocio pequeño (tiene pocos empleados o no tiene, por ejemplo tienda, papelería, etc    252.964924
# Es operario de máquinas o conduce vehículos (taxita, chofer)                                            250.901788
# ...

# %%
df.groupby(['FAMI_TIENEINTERNET']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3796362656.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_TIENEINTERNET']).mean()["PUNT_GLOBAL"]
# FAMI_TIENEINTERNET
# -     221.398250
# No    229.598572
# Si    259.363846
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['FAMI_TIENESERVICIOTV']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\239136734.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_TIENESERVICIOTV']).mean()["PUNT_GLOBAL"]
# FAMI_TIENESERVICIOTV
# -     216.967555
# No    235.548915
# Si    251.640539
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['FAMI_TIENECONSOLAVIDEOJUEGOS']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2364158299.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_TIENECONSOLAVIDEOJUEGOS']).mean()["PUNT_GLOBAL"]
# FAMI_TIENECONSOLAVIDEOJUEGOS
# -     213.962392
# No    242.294856
# Si    262.550909
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['ESTU_DEDICACIONINTERNET']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3734481901.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_DEDICACIONINTERNET']).mean()["PUNT_GLOBAL"]
# ESTU_DEDICACIONINTERNET
# -                        215.963823
# 30 minutos o menos       231.565176
# Entre 1 y 3 horas        258.858775
# Entre 30 y 60 minutos    242.919350
# Más de 3 horas           259.506801
# No Navega Internet       221.351533
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['ESTU_HORASSEMANATRABAJA']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2582843602.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_HORASSEMANATRABAJA']).mean()["PUNT_GLOBAL"]
# ESTU_HORASSEMANATRABAJA
# -                      233.367315
# 0                      254.022646
# Entre 11 y 20 horas    232.544873
# Entre 21 y 30 horas    228.894695
# Menos de 10 horas      233.972251
# Más de 30 horas        219.729593
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['ESTU_TIPOREMUNERACION']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\418272803.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_TIPOREMUNERACION']).mean()["PUNT_GLOBAL"]
# ESTU_TIPOREMUNERACION
# -                            230.124662
# No                           250.462439
# Si, en efectivo              237.330346
# Si, en efectivo y especie    234.615134
# Si, en especie               232.227902
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['COLE_CALENDARIO']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2018289499.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['COLE_CALENDARIO']).mean()["PUNT_GLOBAL"]
# COLE_CALENDARIO
# A       246.367879
# B       233.873684
# OTRO    219.610533
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['COLE_BILINGUE']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\191442664.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['COLE_BILINGUE']).mean()["PUNT_GLOBAL"]
# COLE_BILINGUE
# -    236.649030
# N    248.078881
# S    241.837818
# Name: PUNT_GLOBAL, dtype: float64

# %%
df.groupby(['COLE_GENERO']).mean()["PUNT_GLOBAL"]
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3905330129.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['COLE_GENERO']).mean()["PUNT_GLOBAL"]
# COLE_GENERO
# FEMENINO     282.605779
# MASCULINO    293.601763
# MIXTO        244.903292
# Name: PUNT_GLOBAL, dtype: float64

# %%
df["ESTU_GENERO"].value_counts()
df.groupby(['ESTU_GENERO']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (10,10)
sns.boxplot( x = 'ESTU_GENERO',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\818918807.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_GENERO']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='ESTU_GENERO', ylabel='PUNT_GLOBAL'>

# %%
df["COLE_GENERO"].value_counts()
df.groupby(['COLE_GENERO']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (10,10)
sns.boxplot( x = 'COLE_GENERO',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\3241646204.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['COLE_GENERO']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='COLE_GENERO', ylabel='PUNT_GLOBAL'>

# %%
df["FAMI_EDUCACIONPADRE"].value_counts()
df.groupby(['FAMI_EDUCACIONPADRE']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (45,10)
sns.boxplot( x = 'FAMI_EDUCACIONPADRE',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\558651950.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_EDUCACIONPADRE']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='FAMI_EDUCACIONPADRE', ylabel='PUNT_GLOBAL'>

# %%
df["FAMI_EDUCACIONMADRE"].value_counts()
df.groupby(['FAMI_EDUCACIONMADRE']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (45,10)
sns.boxplot( x = 'FAMI_EDUCACIONMADRE',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\1796598794.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['FAMI_EDUCACIONMADRE']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='FAMI_EDUCACIONMADRE', ylabel='PUNT_GLOBAL'>

# %%
df["ESTU_NACIONALIDAD"].value_counts()
df.groupby(['ESTU_NACIONALIDAD']).mean()["PUNT_GLOBAL"]
plt.rcParams["figure.figsize"] = (45,10)
sns.boxplot( x = 'ESTU_NACIONALIDAD',y = 'PUNT_GLOBAL', width=0.5, data = df)
# Out:
# C:\Users\wdmoreno\AppData\Local\Temp\ipykernel_22500\2007305751.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['ESTU_NACIONALIDAD']).mean()["PUNT_GLOBAL"]
# <AxesSubplot: xlabel='ESTU_NACIONALIDAD', ylabel='PUNT_GLOBAL'>

# %%
categorical_columns=df.drop(columns=df.describe().columns)
for i in categorical_columns.columns:
    print("For the column ",i, " we can have:")
    a=categorical_columns[i].value_counts()
    print(a)
# Out:
# For the column  ESTU_TIPODOCUMENTO  we can have:
# TI     445780
# CC      91921
# CR       6123
# CE       1225
# NES       822
# PEP       235
# PE         91
# PC          6
# RC          5
# CCB         4
# Name: ESTU_TIPODOCUMENTO, dtype: int64
# For the column  ESTU_NACIONALIDAD  we can have:
# COLOMBIA                  544918
# VENEZUELA                   1109
# ESTADOS UNIDOS                52
# ESPAÑA                        33
# ECUADOR                       26
# PERÚ                           7
# CUBA                           6
# MÉXICO                         6
# BRASIL                         5
# ITALIA                         5
# BOLIVIA                        5
# COSTA RICA                     4
# ARGENTINA                      4
# FRANCIA                        3
# COMORAS                        3
# CHILE                          3
# EL SALVADOR                    3
# PAÍSES BAJOS - HOLANDA         2
# CHINA                          2
# ...

# %% [markdown]
# # Data cleaning

# %%
df = df.replace('-', float('nan'))
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# ESTU_TIPODOCUMENTO              0
# ESTU_NACIONALIDAD               0
# ESTU_GENERO                   121
# ESTU_FECHANACIMIENTO            0
# PERIODO                         0
#                             ...
# ESTU_INSE_INDIVIDUAL        17045
# ESTU_NSE_INDIVIDUAL         17045
# ESTU_NSE_ESTABLECIMIENTO       44
# ESTU_ESTADOINVESTIGACION        0
# ESTU_GENERACION-E               0
# Length: 82, dtype: int64

# %%
percent_missing = (missing_values / len(df)) * 100
print(percent_missing)
# Out:
# ESTU_TIPODOCUMENTO          0.000000
# ESTU_NACIONALIDAD           0.000000
# ESTU_GENERO                 0.022153
# ESTU_FECHANACIMIENTO        0.000000
# PERIODO                     0.000000
#                               ...
# ESTU_INSE_INDIVIDUAL        3.120583
# ESTU_NSE_INDIVIDUAL         3.120583
# ESTU_NSE_ESTABLECIMIENTO    0.008055
# ESTU_ESTADOINVESTIGACION    0.000000
# ESTU_GENERACION-E           0.000000
# Length: 82, dtype: float64

# %%
missing_data = pd.concat([missing_values, percent_missing], axis=1, keys=['Total', 'Percent'])
print(missing_data)
# Out:
#                           Total   Percent
# ESTU_TIPODOCUMENTO            0  0.000000
# ESTU_NACIONALIDAD             0  0.000000
# ESTU_GENERO                 121  0.022153
# ESTU_FECHANACIMIENTO          0  0.000000
# PERIODO                       0  0.000000
# ...                         ...       ...
# ESTU_INSE_INDIVIDUAL      17045  3.120583
# ESTU_NSE_INDIVIDUAL       17045  3.120583
# ESTU_NSE_ESTABLECIMIENTO     44  0.008055
# ESTU_ESTADOINVESTIGACION      0  0.000000
# ESTU_GENERACION-E             0  0.000000
#
# [82 rows x 2 columns]

# %%
missing_data = missing_data.sort_values('Percent', ascending=False)
print(missing_data[:30])
# Out:
#                                 Total    Percent
# ESTU_ETNIA                     506203  92.675188
# COLE_BILINGUE                   87432  16.006972
# FAMI_NUMLIBROS                  44652   8.174848
# FAMI_COMELECHEDERIVADOS         36692   6.717538
# FAMI_ESTRATOVIVIENDA            34507   6.317510
# FAMI_COMECEREALFRUTOSLEGUMBRE   33578   6.147430
# ESTU_DEDICACIONINTERNET         32924   6.027696
# FAMI_COMECARNEPESCADOHUEVO      32530   5.955563
# FAMI_TIENESERVICIOTV            31927   5.845166
# ESTU_DEDICACIONLECTURADIARIA    31735   5.810015
# FAMI_TIENEINTERNET              30971   5.670143
# FAMI_EDUCACIONPADRE             30527   5.588856
# FAMI_EDUCACIONMADRE             30367   5.559563
# FAMI_TRABAJOLABORPADRE          18304   3.351080
# ESTU_TIPOREMUNERACION           18099   3.313549
# FAMI_TIENECONSOLAVIDEOJUEGOS    18095   3.312816
# FAMI_TIENEAUTOMOVIL             18089   3.311718
# FAMI_SITUACIONECONOMICA         17875   3.272539
# ...

# %%
df1=df.drop(['ESTU_ETNIA','COLE_BILINGUE'], axis=1)

print("After delete column ESTU_ETNIA and COLE_BILINGUE\n")
print("Numbers of rows: ", df1.shape[0])
print("Numbers of columns: ", df1.shape[1])

# Eliminamos todas las filas con valores nulos
df2 = df1.dropna(how='any')

print("\nAfter delete all empty rows\n")
print("Numbers of rows: ", df2.shape[0])
print("Numbers of columns: ", df2.shape[1])


print("Porcentage reduction data\n")
print("Reduction of rows: ", 100*(1-(df2.shape[0]/df.shape[0])))
print("Reduction of columns: ", 100*(1-(df2.shape[1]/df.shape[1])))
# Out:
# After delete column ESTU_ETNIA and COLE_BILINGUE
#
# Numbers of rows:  546212
# Numbers of columns:  80
#
# After delete all empty rows
#
# Numbers of rows:  450839
# Numbers of columns:  80
# Porcentage reduction data
#
# Reduction of rows:  17.460802765226692
# Reduction of columns:  2.4390243902439046
